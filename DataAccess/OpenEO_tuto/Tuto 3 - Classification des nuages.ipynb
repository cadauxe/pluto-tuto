# %% [markdown]
# # Tutorial 3 : Use case example - Cloud classification

# %% [markdown]
# This notebook demonstrates cloud classification using a Random Forest algorithm through the OpenEO API. The Sentinel-2 dataset includes the Scene Classification Layer (SCL), which is simplified into three categories: background, cloud shadow, and cloud. The processed SCL is used as training data for the Random Forest model to predict clouds and cloud shadows. The trained model is then applied to test data.

# %%
#Imports
import openeo
import xarray
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openeo.processes import if_, and_
import rioxarray
import geopandas
import geojson
from openeo.rest.mlmodel import MlModel

# %% [markdown]
# Establish an authenticated connection to Copernicus Data Space Ecosystem openEO back-end.

# %%
connection = openeo.connect(url="openeo.dataspace.copernicus.eu/")
connection.authenticate_oidc()
# Out:
# Authenticated using refresh token.
# <Connection to 'https://openeo.dataspace.copernicus.eu/openeo/1.2/' with OidcBearerAuth>

# %% [markdown]
# ### Creating Datacube

# %% [markdown]
# Once connected to the OpenEO backend, we initialize a datacube object using the Sentinel-2 L2A data collection. We focus on the time period between May 1st and June 16th, 2023.
#
# We select the spectral bands :
# - B02 (Blue)
# - B03 (Green)
# - B04 (Red)
# - B08 (Near Infrared)
# - SCL (Scene Classification Layer)

# %%
# Get detailed description of one of them
connection.describe_collection("SENTINEL2_L2A")
# Out:
# {'assets': {'thumbnail': {'href': 'https://www.esa.int/var/esa/storage/images/esa_multimedia/images/2022/07/tallinn_estonia/24383281-1-eng-GB/Tallinn_Estonia_pillars.jpg',
#    'roles': ['thumbnail'],
#    'title': 'Sentinel 2 L2A',
#    'type': 'image/png'}},
#  'cube:dimensions': {'bands': {'type': 'bands',
#    'values': ['B01',
#     'B02',
#     'B03',
#     'B04',
#     'B05',
#     'B06',
#     'B07',
#     'B08',
#     'B8A',
#     'B09',
#     'B11',
#     'B12',
#     'WVP',
#     'AOT',
#     'SCL',
#     'sunAzimuthAngles',
#     'sunZenithAngles',
#     'viewAzimuthMean',
#     'viewZenithMean']},
#   't': {'extent': ['2015-07-04T00:00:00Z', None], 'type': 'temporal'},
#   'x': {'axis': 'x',
#    'extent': [-180, 180],
#    'reference_system': {'$schema': 'https://proj.org/schemas/v0.2/projjson.schema.json',
#     'area': 'World',
#     'bbox': {'east_longitude': 180,
#      'north_latitude': 90,
#      'south_latitude': -90,
#      'west_longitude': -180},
#     'coordinate_system': {'axis': [{'abbreviation': 'Lat',
#        'direction': 'north',
#        'name': 'Geodetic latitude',
#        'unit': 'degree'},
#       {'abbreviation': 'Lon',
#        'direction': 'east',
#        'name': 'Geodetic longitude',
#        'unit': 'degree'}],
#      'subtype': 'ellipsoidal'},
#     'datum': {'ellipsoid': {'inverse_flattening': 298.257223563,
#       'name': 'WGS 84',
#       'semi_major_axis': 6378137},
#      'name': 'World Geodetic System 1984',
#      'type': 'GeodeticReferenceFrame'},
#     'id': {'authority': 'OGC', 'code': 'Auto42001', 'version': '1.3'},
#     'name': 'AUTO 42001 (Universal Transverse Mercator)',
#     'type': 'GeodeticCRS'},
#    'step': 10,
#    'type': 'spatial'},
#   'y': {'axis': 'y',
#    'extent': [-56, 83],
#    'reference_system': {'$schema': 'https://proj.org/schemas/v0.2/projjson.schema.json',
#     'area': 'World',
#     'bbox': {'east_longitude': 180,
#      'north_latitude': 90,
#      'south_latitude': -90,
#      'west_longitude': -180},
#     'coordinate_system': {'axis': [{'abbreviation': 'Lat',
#        'direction': 'north',
#        'name': 'Geodetic latitude',
#        'unit': 'degree'},
#       {'abbreviation': 'Lon',
#        'direction': 'east',
#        'name': 'Geodetic longitude',
#        'unit': 'degree'}],
#      'subtype': 'ellipsoidal'},
#     'datum': {'ellipsoid': {'inverse_flattening': 298.257223563,
#       'name': 'WGS 84',
#       'semi_major_axis': 6378137},
#      'name': 'World Geodetic System 1984',
#      'type': 'GeodeticReferenceFrame'},
#     'id': {'authority': 'OGC', 'code': 'Auto42001', 'version': '1.3'},
#     'name': 'AUTO 42001 (Universal Transverse Mercator)',
#     'type': 'GeodeticCRS'},
#    'step': 10,
#    'type': 'spatial'}},
#  'description': 'SENTINEL-2 is a wide-swath, high-resolution, multi-spectral imaging mission, supporting Copernicus Land Monitoring studies, including the monitoring of vegetation, soil and water cover, as well as observation of inland waterways and coastal areas. The SENTINEL-2 Multispectral Instrument (MSI) samples 13 spectral bands: four bands at 10 metres, six bands at 20 metres and three bands at 60 metres spatial resolution.\n The level 2A data is atmospherically corrected using Sen2Cor.',
#  'extent': {'spatial': {'bbox': [[-180, -56, 180, 83]]},
#   'temporal': {'interval': [['2015-07-04T00:00:00Z', None]]}},
#  'id': 'SENTINEL2_L2A',
#  'keywords': ['COPERNICUS',
#   'ESA',
#   'Orthoimagery',
#   'Sentinel-2',
#   'MSI',
#   'Level-2A',
#   'Radiometry',
#   'Plant Resource',
#   'TOC'],
#  'license': 'proprietary',
#  'links': [{'href': 'https://sentinels.copernicus.eu/documents/247904/690755/Sentinel_Data_Legal_Notice',
#    'rel': 'license',
#    'type': 'application/pdf'},
#   {'href': 'https://documentation.dataspace.copernicus.eu/Data/SentinelMissions/Sentinel2.html#sentinel-2-level-2a-top-of-canopy-toc',
#    'rel': 'alternate',
#    'type': 'application/html'},
#   {'href': 'https://dataspace.copernicus.eu/browser/?zoom=11&lat=45.36638&lng=12.49832&themeId=DEFAULT-THEME&visualizationUrl=https%3A%2F%2Fsh.dataspace.copernicus.eu%2Fogc%2Fwms%2F28b654e7-8912-4e59-9e58-85b58d768b3a&datasetId=S2_L2A_CDAS&fromTime=2023-02-07T00%3A00%3A00.000Z&toTime=2023-02-07T23%3A59%3A59.999Z&layerId=1_TRUE_COLOR&demSource3D=%22MAPZEN%22&cloudCoverage=10',
#    'rel': 'browser',
#    'title': 'CDSE Data-Browser'},
#   {'href': 'https://catalogue.dataspace.copernicus.eu/resto/api/collections/Sentinel2/search.json?cloudCover=[0,10]&productType=S2MSI2A&startDate=2022-06-11&completionDate=2022-06-22&maxRecords=10',
#    'rel': 'opensearch',
#    'title': 'Opensearch product query'},
#   {'href': 'https://sentinels.copernicus.eu/web/sentinel/user-guides/sentinel-2-msi/product-types/level-2a',
#    'rel': 'about',
#    'title': 'User guide'},
#   {'href': 'https://services.sentinel-hub.com/ogc/wmts/7d34803f-511c-4caf-9438-6d72f32c8174',
#    'rel': 'wmts',
#    'title': 'Web Map Tile Service',
#    'wmts:dimensions': {'warnings': True},
#    'wmts:layer': 'TRUE-COLOR'},
#   {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections',
#    'rel': 'root'},
#   {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections',
#    'rel': 'parent'},
#   {'href': 'https://openeo.dataspace.copernicus.eu/openeo/1.2/collections/SENTINEL2_L2A',
#    'rel': 'self'}],
#  'mission': 'Sentinel-2',
#  'name': 'SENTINEL2_L2A',
#  'providers': [{'name': 'ESA',
#    'roles': ['producer'],
#    'url': 'https://esa.int/'},
#   {'name': 'CDSE',
#    'roles': ['processor', 'host'],
#    'url': 'https://dataspace.copernicus.eu/'}],
#  'stac_extensions': ['https://stac-extensions.github.io/datacube/v2.2.0/schema.json',
#   'https://stac-extensions.github.io/eo/v1.1.0/schema.json'],
#  'stac_version': '0.9.0',
#  'summaries': {'constellation': ['sentinel-2'],
#   'eo:bands': [{'aliases': ['IMG_DATA_Band_B01_60m_Tile1_Data'],
#     'center_wavelength': 0.4427,
#     'common_name': 'coastal',
#     'full_width_half_max': 0.021,
#     'gsd': 60,
#     'name': 'B01',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B02_10m_Tile1_Data'],
#     'center_wavelength': 0.4924,
#     'common_name': 'blue',
#     'full_width_half_max': 0.066,
#     'gsd': 10,
#     'name': 'B02',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B03_10m_Tile1_Data'],
#     'center_wavelength': 0.5598,
#     'common_name': 'green',
#     'full_width_half_max': 0.036,
#     'gsd': 10,
#     'name': 'B03',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B04_10m_Tile1_Data'],
#     'center_wavelength': 0.6646,
#     'common_name': 'red',
#     'full_width_half_max': 0.031,
#     'gsd': 10,
#     'name': 'B04',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B05_20m_Tile1_Data'],
#     'center_wavelength': 0.7041,
#     'full_width_half_max': 0.015,
#     'gsd': 20,
#     'name': 'B05',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B06_20m_Tile1_Data'],
#     'center_wavelength': 0.7405,
#     'full_width_half_max': 0.015,
#     'gsd': 20,
#     'name': 'B06',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B07_20m_Tile1_Data'],
#     'center_wavelength': 0.7828,
#     'full_width_half_max': 0.02,
#     'gsd': 20,
#     'name': 'B07',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B08_10m_Tile1_Data'],
#     'center_wavelength': 0.8328,
#     'common_name': 'nir',
#     'full_width_half_max': 0.106,
#     'gsd': 10,
#     'name': 'B08',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B8A_20m_Tile1_Data'],
#     'center_wavelength': 0.8647,
#     'common_name': 'nir08',
#     'full_width_half_max': 0.021,
#     'gsd': 20,
#     'name': 'B8A',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B09_60m_Tile1_Data'],
#     'center_wavelength': 0.9451,
#     'common_name': 'nir09',
#     'full_width_half_max': 0.02,
#     'gsd': 60,
#     'name': 'B09',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B11_20m_Tile1_Data'],
#     'center_wavelength': 1.6137,
#     'common_name': 'swir16',
#     'full_width_half_max': 0.091,
#     'gsd': 20,
#     'name': 'B11',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_B12_20m_Tile1_Data'],
#     'center_wavelength': 2.2024,
#     'common_name': 'swir22',
#     'full_width_half_max': 0.175,
#     'gsd': 20,
#     'name': 'B12',
#     'offset': 0,
#     'scale': 0.0001,
#     'type': 'int16',
#     'unit': '1'},
#    {'aliases': ['IMG_DATA_Band_WVP_10m_Tile1_Data'], 'name': 'WVP'},
#    {'aliases': ['IMG_DATA_Band_AOT_20m_Tile1_Data'], 'name': 'AOT'},
#    {'aliases': ['IMG_DATA_Band_SCL_20m_Tile1_Data'], 'gsd': 20, 'name': 'SCL'},
#    {'aliases': ['S2_Level-2A_Tile1_Metadata##0', 'SAA'],
#     'name': 'sunAzimuthAngles',
#     'unit': 'deg'},
#    {'aliases': ['S2_Level-2A_Tile1_Metadata##1', 'SZA'],
#     'name': 'sunZenithAngles',
#     'unit': 'deg'},
#    {'aliases': ['S2_Level-2A_Tile1_Metadata##2',
#      'VAA',
#      'approximateViewAzimuth'],
#     'name': 'viewAzimuthMean',
#     'unit': 'deg'},
#    {'aliases': ['S2_Level-2A_Tile1_Metadata##3',
#      'VZA',
#      'approximateViewZenith'],
#     'name': 'viewZenithMean',
#     'unit': 'deg'}],
#   'eo:cloud_cover': {'maximum': 100, 'minimum': 0},
#   'gsd': [10],
#   'instrument': ['msi'],
#   'platform': ['sentinel-2a', 'sentinel-2b'],
#   'productIdentifier': {}},
#  'title': 'Sentinel-2 L2A'}

# %%
s2_timeseries = connection.load_collection(
    "SENTINEL2_L2A",
    temporal_extent=("2023-05-01", "2023-06-16"),
    spatial_extent={
        "west":  2.213649,
        "south": 43.450702,
        "east": 2.251248,
        "north":  43.472631,
        "crs": "EPSG:4326",
    },
    bands=["B02", "B03", "B04", "B08", "SCL"],
    max_cloud_cover=50,
);

# %% [markdown]
# We will use the **Scene Classification Layer** (SCL) as a reference for our Random Forest classification.
#
# This layer provides a classification of the Earth's surface that includes categories such as vegetation, water, clouds and cloud shadows.
#
# The SCL classifications are described in detail on the [Sentinel-2 Processing Wiki](https://sentiwiki.copernicus.eu/web/s2-processing). The image bellow provides the different labels that are associated to each class of the SCL.
# <div style="text-align: center;">
#     <img src="images/tuto_classification/esa_class.png" alt="" width="600"/>
# </div>

# %% [markdown]
# ## Exporting and visualizing data

# %% [markdown]
# To vizualize the Sentinel-2 data we export it to the NetCDF format and we plot the first  and the last image of the timeseries.
#
# The RGB bands and their corresponding SCL are plotted side by side.

# %%
#Download the data to the NetCDF format
s2_timeseries.download("output/s2_timeseries.nc")

# %%
# Load the Sentinel-2 time series dataset from a NetCDF file
s2_datarray = xarray.load_dataset("output/s2_timeseries.nc")

# Extract the SCL and the RGB bands as arrays to plot them
scl_arr = s2_datarray[["SCL"]].to_array(dim="bands")
rgb_arr = s2_datarray[["B04", "B03", "B02"]].to_array(dim="bands")

# Plotting the first image of the timeseries, and it's SCL band
fig, axes = plt.subplots(ncols=2, figsize=(9, 3), dpi=100, sharey=True)
#vmin and vmax are for the range of the colormap
rgb_arr[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
scl_arr[{"t": 0}].isel(bands=0).plot.imshow(vmin=3, vmax=10, ax=axes[1])

# Plotting the last image of the timeseries, and it's SCL band
fig, axes = plt.subplots(ncols=2, figsize=(9, 3), dpi=100, sharey=True)
#vmin and vmax are for the range of the colormap
rgb_arr[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
scl_arr[{"t": -1}].isel(bands=0).plot.imshow(vmin=3, vmax=10, ax=axes[1])

# %%
np.unique(scl_arr.isel(bands=0).values)
# Out:
# array([ 3.,  4.,  5.,  7.,  8.,  9., 10.], dtype=float32)

# %% [markdown]
# The SCL in the timeseries  contains seven classes : "Unclassified", "Cloud medium probability", "Thin cirrus", "Cloud high probability", "Cloud shadow", "Vegetation" and "Not vegetated".
#
# To simplify the SCL for our classification algorithm, we group these classes into three wider categories with the following labels:
# - **3 : Background** – Combines "Vegetation," "Not vegetated," and "Unclassified".
# - **4 : Cloud shadow** – Retains the original "Cloud shadow" class.
# - **7 : Cloud** – Combines "Thin cirrus," "Cloud medium probability," and "Cloud high probability".

# %%
# Extracting classification band from the datacube
scl_band = s2_timeseries.band("SCL")

# The pixels that are above 7 are labeled as clouds
scl_labels = scl_band.apply(lambda x: if_(x > 7, 7, x))

# The pixels whose values are 4 or 5 are labeled as no clouds
scl_labels = scl_labels.apply(lambda x: if_(and_(x > 3, x < 6), 4, x))

# %% [markdown]
# We export the modified SCL to the NetCDF format to visualize the changes. In the plot below, clouds appear turquoise, cloud shadows are dark blue and the background is medium blue.

# %%
#Download the modified SCL data to the NetCDF format
scl_labels.download("output/cloud_mask.nc")

# %%
class_data = xarray.load_dataset("output/cloud_mask.nc")
# Convert xarray DataSet to a (bands, t, x, y) DataArray
scl_modif = class_data[["var"]].to_array(dim="bands")

# Plotting the first image of the timeseries, and it's SCL band
fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=100, sharey=True, sharex=True)
#vmin and vmax are for the range of the colormap
rgb_arr[{"t": 0}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
scl_modif[{"t": 0}].isel(bands=0).plot.imshow(vmin=3, vmax=10, ax=axes[1])

# Plotting the last image of the timeseries, and it's SCL band
fig, axes = plt.subplots(ncols=2, figsize=(8, 3), dpi=100, sharey=True, sharex=True)
#vmin and vmax are for the range of the colormap
rgb_arr[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
scl_modif[{"t": -1}].isel(bands=0).plot.imshow(vmin=3, vmax=10, ax=axes[1])

# %% [markdown]
# We can confirm that only three categories remain in the modified SCL band by displaying all the unique values it contains.

# %%
np.unique(scl_modif.isel(bands=0).values)
# Out:
# array([3, 4, 7], dtype=int32)

# %% [markdown]
# ## Building the training and test datasets

# %% [markdown]
# The image from May 2nd will be used for training, and the image from June 4th will be used for testing.
#
# We select the corresponding image of the timeseries with the *.reduce_dimension()* method. We then download both files in the GeoTIFF format.

# %%
# Selecting the first temporal image for SCL
scl_train = scl_labels.reduce_dimension(dimension="t", reducer="first")

#Download the data to GeoTiff
scl_train.download("output/cloud_train.tiff", format="GTIFF")

# Selecting RGB abd NIR bands
rgb_nir = s2_timeseries.filter_bands(["B02", "B03", "B04", "B08"])

# Selecting the first temporal image for RBG and NIR Bands
train_cube = rgb_nir.reduce_dimension(dimension="t", reducer="first")

# %%
# Selecting the last temporal image for SCL
scl_test = scl_labels.reduce_dimension(dimension="t", reducer="last")

#Download the data to GeoTiff
scl_test.download("output/cloud_test.tiff", format="GTIFF")

# Selecting the last temporal image for RBG and NIR Bands
test_cube = rgb_nir.reduce_dimension(dimension="t", reducer="last")

# %% [markdown]
# ### Building the feature collection

# %% [markdown]
# We load the provided GeoJSON file to create a FeatureCollection of labeled and georeferenced points for the training data.

# %%
with open("output/cloud_class.geojson") as f:
    gj_data = geojson.load(f)

# %%
feature_collection = {"type": "FeatureCollection", "features": None}

point_list = []
feature_dict = {
            "type": "Feature",
            "properties": {"id": "null", "target": None},
            "geometry": {"type": "Point", "coordinates": None}}


for labeled_point in gj_data["features"]:
    feature_dict = {
            "type": "Feature",
            "properties": {"id": "null", "target": None},
            "geometry": {"type": "Point", "coordinates": None}}
    
    feature_dict["geometry"]["coordinates"] = labeled_point["geometry"]["coordinates"]
    feature_dict["properties"]["target"] = labeled_point["properties"]["target"]
    point_list.append(feature_dict)

feature_collection["features"] = point_list

# %%
#Displaying the feature collection
feature_collection
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.221382, 43.465292]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.218806, 43.465604]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.221382, 43.465994]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.228211, 43.459244]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.225518, 43.459009]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.250375, 43.471145]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.250609, 43.472199]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.233791, 43.457331]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.231137, 43.460687]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.214592, 43.469936]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.215021, 43.468921]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.217792, 43.464004]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.222279, 43.457175]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.22825, 43.455263]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.228913, 43.460453]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.229596, 43.452551]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.224386, 43.457897]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.23024, 43.459848]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.22626, 43.460375]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.220153, 43.46537]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.238571, 43.46455]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.232249, 43.469389]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.243136, 43.465292]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.24341, 43.454171]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.219723, 43.457253]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.226981, 43.452142]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.220387, 43.452649]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.227801, 43.463692]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.235176, 43.4514]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.236269, 43.456785]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.231664, 43.463224]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.224874, 43.465448]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.217421, 43.462209]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.217304, 43.45659]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.248951, 43.461819]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.244697, 43.468101]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.240522, 43.470755]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.247741, 43.452766]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.227567, 43.469936]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.21828, 43.454249]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.232405, 43.466931]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.222689, 43.470287]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.220426, 43.461546]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.222611, 43.462014]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.220582, 43.460336]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.219879, 43.463497]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.221792, 43.462912]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.21906, 43.46139]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.22343, 43.460765]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.223899, 43.454366]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.224328, 43.455849]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.230688, 43.450932]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.232444, 43.452805]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.231118, 43.454834]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.234474, 43.454483]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.230064, 43.457019]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.251019, 43.469545]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.226708, 43.456005]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.232679, 43.4546]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.230688, 43.458034]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.234981, 43.458522]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.236659, 43.453859]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.251351, 43.469136]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.224972, 43.454502]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.217421, 43.465663]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.225889, 43.457741]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.226094, 43.457049]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.226718, 43.454483]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.228445, 43.454063]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.21864, 43.455839]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.219733, 43.458766]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.217275, 43.459663]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.219226, 43.462395]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.232883, 43.456073]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.231518, 43.457049]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.229645, 43.451546]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.230152, 43.4542]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.234327, 43.452795]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.234444, 43.455644]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.219538, 43.460326]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.220709, 43.462551]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.228708, 43.457712]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.22344, 43.462668]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.222318, 43.459692]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.250673, 43.469428]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.23483, 43.453629]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.23522, 43.458975]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.226747, 43.453976]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.226147, 43.462629]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.228059, 43.462277]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.224704, 43.463682]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.221426, 43.454863]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.236332, 43.45541]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.232186, 43.459292]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.232801, 43.459575]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.231708, 43.459244]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.223182, 43.467399]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.215211, 43.464999]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.215797, 43.452824]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.245766, 43.458053]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.2396, 43.467575]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.234644, 43.462931]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.239366, 43.460902]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.239366, 43.457702]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.235386, 43.467419]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.228908, 43.464765]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.228011, 43.466365]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.232381, 43.464726]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.236908, 43.464141]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.223737, 43.467831]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.234311, 43.460974]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.219458, 43.470593]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.229508, 43.471849]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.235005, 43.47143]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.245632, 43.472163]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.239612, 43.451381]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.249819, 43.45091]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.249401, 43.457558]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.242635, 43.459227]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.218522, 43.45801]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.220485, 43.468348]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 4},
#    'geometry': {'type': 'Point', 'coordinates': [2.224751, 43.460339]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.220145, 43.465626]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.229986, 43.461438]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.222814, 43.45801]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.222605, 43.456308]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.2275, 43.455209]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.233206, 43.457669]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.23208, 43.458769]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.230222, 43.45568]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.223364, 43.463925]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.223155, 43.459004]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.222553, 43.464946]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.21491, 43.470547]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.215643, 43.469055]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.213915, 43.469526]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.249446, 43.471672]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.250559, 43.470586]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.251082, 43.471241]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.250088, 43.472732]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.25103, 43.472274]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 3},
#    'geometry': {'type': 'Point', 'coordinates': [2.249512, 43.470926]}},
#   {'type': 'Feature',
#    'properties': {'id': 'null', 'target': 7},
#    'geometry': {'type': 'Point', 'coordinates': [2.251318, 43.469997]}}]}

# %% [markdown]
# ## Training the Random Forest Model

# %% [markdown]
# We compute the mean of the B02/B03/B04/B08 band values of train_cube at the spatial points defined in *feature_collection*.

# %%
predictors = train_cube.aggregate_spatial(feature_collection, reducer="mean")

# %% [markdown]
# We now train our Random Forest model and execute the training flow as a batch job.

# %%
#Configure the Training of the Random Forest Model
model = predictors.fit_class_random_forest(
    target=feature_collection,
)

# Save the model as a batch job result asset so that we can load it in another job.
model = model.save_ml_model()

# %%
job_options = {
    "executor-memory": "3G",
    "executor-memoryOverhead": "4G",
}

# %%
# Running the job
training_job = model.create_job(
    title="Training-job Dynamic LC", job_options=job_options
)
training_job.start_and_wait()
# Out:
# 0:00:00 Job 'j-241226a975994cddb6bdb514ea824dce': send 'start'
# 0:00:15 Job 'j-241226a975994cddb6bdb514ea824dce': created (progress 0%)
# 0:00:21 Job 'j-241226a975994cddb6bdb514ea824dce': created (progress 0%)
# 0:00:28 Job 'j-241226a975994cddb6bdb514ea824dce': created (progress 0%)
# 0:00:37 Job 'j-241226a975994cddb6bdb514ea824dce': created (progress 0%)
# 0:00:47 Job 'j-241226a975994cddb6bdb514ea824dce': created (progress 0%)
# 0:01:01 Job 'j-241226a975994cddb6bdb514ea824dce': running (progress N/A)
# 0:01:17 Job 'j-241226a975994cddb6bdb514ea824dce': running (progress N/A)
# 0:01:36 Job 'j-241226a975994cddb6bdb514ea824dce': running (progress N/A)
# 0:02:01 Job 'j-241226a975994cddb6bdb514ea824dce': running (progress N/A)
# 0:02:31 Job 'j-241226a975994cddb6bdb514ea824dce': running (progress N/A)
# 0:03:09 Job 'j-241226a975994cddb6bdb514ea824dce': finished (progress 100%)
# <BatchJob job_id='j-241226a975994cddb6bdb514ea824dce'>

# %%
# Importing the results
results = training_job.get_results()
results.download_files()
# Out:
# [PosixPath('/home/ecadaux/Documents/work/pluto-tuto/DataAccess/OpenEO_tuto/randomforest.model.tar.gz'),
#  PosixPath('/home/ecadaux/Documents/work/pluto-tuto/DataAccess/OpenEO_tuto/job-results.json')]

# %%
links = results.get_metadata()["links"]
ml_model_metadata_url = [
    link for link in links if "ml_model_metadata.json" in link["href"]
][0]["href"]
print(ml_model_metadata_url)
# Out:
# https://openeo.dataspace.copernicus.eu/openeo/1.2/jobs/j-241226a975994cddb6bdb514ea824dce/results/items/NzRjYjFjYWItNTYxNi00MzA5LWE1MzYtMTkzNzE1N2I1Y2Y2/b014d9e08d7b7ef6d30abfcad2dfbb8e/ml_model_metadata.json?expires=1735813224

# %%
# Loading the random Forest model
model = MlModel.load_ml_model(connection=connection, id=ml_model_metadata_url)

# %% [markdown]
# ## Prediction of the test dataset

# %% [markdown]
# We can now predict the class of our test dataset with our trained model. The predictions are processed in batch and saved as GeoTIFF files.

# %%
predicted = (
    test_cube.predict_random_forest(model=model, dimension="bands")
) 
test_job = predicted.execute_batch(
    out_format="GTiff", title="cloud prediction"
)
test_job.get_results().download_files()
# Out:
# 0:00:00 Job 'j-2412268bfe624a93809f6d980a63cca9': send 'start'
# 0:00:18 Job 'j-2412268bfe624a93809f6d980a63cca9': created (progress 0%)
# 0:00:23 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:00:31 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:00:39 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:00:49 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:01:02 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:01:18 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:01:37 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:02:02 Job 'j-2412268bfe624a93809f6d980a63cca9': running (progress N/A)
# 0:02:32 Job 'j-2412268bfe624a93809f6d980a63cca9': finished (progress 100%)
# [PosixPath('/home/ecadaux/Documents/work/pluto-tuto/DataAccess/OpenEO_tuto/openEO.tif'),
#  PosixPath('/home/ecadaux/Documents/work/pluto-tuto/DataAccess/OpenEO_tuto/job-results.json')]

# %% [markdown]
# ## Plotting the result

# %% [markdown]
# We finally plot the random forest prediction and compare it to the reference SCL data.

# %%
predicted_test = rioxarray.open_rasterio('openEO.tif')
ref_test = rioxarray.open_rasterio('output/cloud_test.tiff')

fig, axes = plt.subplots(ncols=3, figsize=(10, 3), dpi=100, sharey=True, sharex=True)
#vmin and vmax are for the range of the colormap
rgb_arr[{"t": -1}].plot.imshow(vmin=0, vmax=2000, ax=axes[0])
axes[0].set_title("RGB Bands")
predicted_test.isel(band=0).plot.imshow(vmin=3, vmax=10, ax=axes[1])
axes[1].set_title("Predicted with Random Forest")
ref_test.isel(band=0).plot.imshow(vmin=3, vmax=10, ax=axes[2])
axes[2].set_title("Reference Test Data")
plt.tight_layout()
